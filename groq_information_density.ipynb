# %% [markdown]
# > 🚨 This Notebook is work in progress.
#
# # Groq: Generative Information Density Experiment 🍞 (GrID)
#
# This notebook services as our experiments in understanding "information density" — as a concept, topic of research, practical tool and natural occurence. We start the experiment with no external knowledge, simply an intuition of what "information density" means to us. From there, we'll gradually evolve our approach by tapping into research literature and existing tools. At the end, we'll present one compact solution that compiles all the findings in the notebook. 👾

# %% [markdown]
# # GrID: Generative Information Density 👩🏻‍🎤
#
# Let's get started with the architecture.
#
# ### Architecture and Design 🛖

# %%
import os

requirements_installed = False
max_retries = 3
retries = 0


def install_requirements():
    """Installs the requirements from requirements.txt file"""
    global requirements_installed
    if requirements_installed:
        print("Requirements already installed.")
        return

    print("Installing requirements...")
    install_status = os.system("pip install -r requirements.txt")
    if install_status == 0:
        print("Requirements installed successfully.")
        requirements_installed = True
    else:
        print("Failed to install requirements.")
        if retries < max_retries:
            print("Retrying...")
            retries += 1
            return install_requirements()
        exit(1)
    return

# %%
install_requirements()
# Out:
# Installing requirements...
# Requirement already satisfied: numpy==1.26.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas==1.5.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: pydantic==2.10.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.10.4)
# Requirement already satisfied: pydantic-settings==2.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.7.1)
# Requirement already satisfied: pydantic_core==2.27.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.27.2)
# Requirement already satisfied: crewai==0.95.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.95.0)
# Requirement already satisfied: crewai-tools==0.25.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.25.8)
# Requirement already satisfied: langchain==0.3.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.3.14)
# Requirement already satisfied: langchain-anthropic==0.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (0.3.1)
# Requirement already satisfied: langchain-cohere==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.3.4)
# Requirement already satisfied: langchain-community==0.3.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.3.14)
# Requirement already satisfied: langchain-core==0.3.29 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.3.29)
# Requirement already satisfied: langchain-experimental==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.3.4)
# Requirement already satisfied: langchain-openai==0.2.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (0.2.14)
# Requirement already satisfied: langchain-text-splitters==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (0.3.4)
# Requirement already satisfied: firecrawl-py==1.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: groq==0.13.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (0.13.1)
# Requirement already satisfied: pandasai==2.4.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (2.4.2)
# Requirement already satisfied: torch==2.5.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (2.5.1)
# Requirement already satisfied: torchaudio==2.5.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (0.20.1)
# Requirement already satisfied: scikit-learn==1.6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (1.6.0)
# Requirement already satisfied: scipy==1.15.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (1.15.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (0.7.6)
# Requirement already satisfied: chromadb==0.5.23 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (0.5.23)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandas==1.5.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandas==1.5.3->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pydantic==2.10.4->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pydantic==2.10.4->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (4.7.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: click>=8.1.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (0.35.0)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.56.10)
# Requirement already satisfied: openai>=1.13.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.59.3)
# Requirement already satisfied: openpyxl>=3.1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.29.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (0.11.5)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 7)) (0.5.14)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.1.126)
# Requirement already satisfied: lancedb>=0.5.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.17.0)
# Requirement already satisfied: linkup-sdk>=0.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: pyright>=1.1.350 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.1.391)
# Requirement already satisfied: pytest>=8.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (8.3.4)
# Requirement already satisfied: pytube>=15.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: scrapegraph-py>=1.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: selenium>=4.18.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (4.27.1)
# Requirement already satisfied: serpapi>=0.1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.1.5)
# Requirement already satisfied: spider-client>=0.1.25 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.1.25)
# Requirement already satisfied: weaviate-client>=4.9.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 8)) (4.10.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 9)) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 9)) (3.11.11)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 9)) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 9)) (9.0.0)
# Requirement already satisfied: anthropic<1,>=0.41.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.1->-r requirements.txt (line 10)) (0.42.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.1->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-cohere==0.3.4->-r requirements.txt (line 11)) (5.13.5)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-cohere==0.3.4->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-community==0.3.14->-r requirements.txt (line 12)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-community==0.3.14->-r requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-core==0.3.29->-r requirements.txt (line 13)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-core==0.3.29->-r requirements.txt (line 13)) (24.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-openai==0.2.14->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: websockets in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from firecrawl-py==1.8.0->-r requirements.txt (line 17)) (14.1)
# Requirement already satisfied: nest-asyncio in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from firecrawl-py==1.8.0->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from groq==0.13.1->-r requirements.txt (line 18)) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from groq==0.13.1->-r requirements.txt (line 18)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from groq==0.13.1->-r requirements.txt (line 18)) (0.27.2)
# Requirement already satisfied: sniffio in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from groq==0.13.1->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: astor<0.9.0,>=0.8.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (0.8.1)
# Requirement already satisfied: duckdb<2.0.0,>=1.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (1.1.3)
# Requirement already satisfied: faker<20.0.0,>=19.12.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (19.13.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (3.1.5)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (3.10.0)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandasai==2.4.2->-r requirements.txt (line 19)) (10.4.0)
# Requirement already satisfied: sqlglot<26.0.0,>=25.0.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai==2.4.2->-r requirements.txt (line 19)) (25.34.1)
# Requirement already satisfied: filelock in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from torch==2.5.1->-r requirements.txt (line 20)) (3.16.1)
# Requirement already satisfied: networkx in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from torch==2.5.1->-r requirements.txt (line 20)) (3.4.2)
# Requirement already satisfied: fsspec in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from torch==2.5.1->-r requirements.txt (line 20)) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from torch==2.5.1->-r requirements.txt (line 20)) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from torch==2.5.1->-r requirements.txt (line 20)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.0->-r requirements.txt (line 23)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.0->-r requirements.txt (line 23)) (3.5.0)
# Requirement already satisfied: build>=1.0.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (1.2.2.post1)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.23->-r requirements.txt (line 26)) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (3.7.5)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (0.50b0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (3.10.13)
# Requirement already satisfied: rich>=10.11.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb==0.5.23->-r requirements.txt (line 26)) (13.9.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.5.1->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 9)) (1.18.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 10)) (0.8.2)
# Requirement already satisfied: idna>=2.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq==0.13.1->-r requirements.txt (line 18)) (3.10)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 7)) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 7)) (2.10.1)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.6)
# Requirement already satisfied: pyproject_hooks in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb==0.5.23->-r requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 11)) (1.10.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 11)) (2.32.0.20241016)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 12)) (3.23.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.75.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.1.44)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.37 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.1.39)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.7.7)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb==0.5.23->-r requirements.txt (line 26)) (0.41.3)
# Requirement already satisfied: certifi in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq==0.13.1->-r requirements.txt (line 18)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq==0.13.1->-r requirements.txt (line 18)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq==0.13.1->-r requirements.txt (line 18)) (0.14.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai==0.95.0->-r requirements.txt (line 7)) (0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.3->pandasai==2.4.2->-r requirements.txt (line 19)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.29->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.17.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.9)
# Requirement already satisfied: deprecation in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: pylance==0.20.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: pyarrow>=14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pylance==0.20.0->lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 8)) (18.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai==2.4.2->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai==2.4.2->-r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai==2.4.2->-r requirements.txt (line 19)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai==2.4.2->-r requirements.txt (line 19)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai==2.4.2->-r requirements.txt (line 19)) (3.2.1)
# Requirement already satisfied: coloredlogs in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.23->-r requirements.txt (line 26)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.23->-r requirements.txt (line 26)) (24.12.23)
# Requirement already satisfied: protobuf in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.23->-r requirements.txt (line 26)) (5.29.2)
# Requirement already satisfied: et-xmlfile in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai==0.95.0->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.22.0->crewai==0.95.0->-r requirements.txt (line 7)) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.23->-r requirements.txt (line 26)) (3.8.1)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 7)) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 7)) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.5.23->-r requirements.txt (line 26)) (2.2.1)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyright>=1.1.350->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.9.1)
# Requirement already satisfied: iniconfig in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (8.31.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (4.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==0.5.23->-r requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==0.5.23->-r requirements.txt (line 26)) (2.18.0)
# Requirement already satisfied: trio~=0.17 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.28.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.11.1)
# Requirement already satisfied: ijson in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from spider-client>=0.1.25->crewai-tools==0.25.8->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: sqlglotrs==0.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai==2.4.2->-r requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb==0.5.23->-r requirements.txt (line 26)) (0.27.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==0.5.23->-r requirements.txt (line 26)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.23->-r requirements.txt (line 26)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.23->-r requirements.txt (line 26)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.23->-r requirements.txt (line 26)) (1.0.3)
# Requirement already satisfied: validators==0.34.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.34.0)
# Requirement already satisfied: authlib<1.3.2,>=1.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: grpcio-tools<2.0.0,>=1.66.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.68.1)
# Requirement already satisfied: grpcio-health-checking<2.0.0,>=1.66.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.68.1)
# Requirement already satisfied: Mako in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.3.8)
# Requirement already satisfied: cffi>=1.12 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (4.9)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.24.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.0.6)
# Requirement already satisfied: zipp>=3.20 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (3.21.0)
# Requirement already satisfied: decorator in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (3.0.48)
# Requirement already satisfied: stack_data in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 7)) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.12.2)
# Requirement already satisfied: sortedcontainers in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.4.0)
# Requirement already satisfied: outcome in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.23->-r requirements.txt (line 26)) (10.0)
# Requirement already satisfied: pycparser in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 7)) (2.22)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.68.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.23->-r requirements.txt (line 26)) (0.6.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (2.10.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: h2<5,>=3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 8)) (4.0.0)
# Requirements installed successfully.

# %%
from dotenv import load_dotenv
import os


def setup_env():
    """Sets up the environment variables"""
    load_dotenv()

    GROQ_API_KEY = os.getenv("GROQ_API_KEY")

    if GROQ_API_KEY is None:
        print("Please set the GROQ_API_KEY environment variable.")
        exit(1)
    else:
        print("GROQ_API_KEY is set.")

# %%
setup_env()
# Out:
# GROQ_API_KEY is set.

# %%
from pydantic import BaseModel
from enum import Enum
from typing import List

class Sentiment(Enum):
    positive = "positive"
    negative = "negative"
    neutral = "neutral"

class StrengthMetric(BaseModel):
    """
    The strength of the metric in the text.
    """
    strength: float
    confidence: float

class TopicScoreNode(StrengthMetric):
    """
    Extracted topic with strength and confidence. 
    The topic strength indicates how strongly the topic is present in the text.
    The confidence indicates how confident the model is in the topic extraction and strength.
    """
    topic: str

class QuestionNode(StrengthMetric):
    """
    Extracted question with strength and confidence. 
    The question strength indicates how strongly the question is present in the text.
    The confidence indicates how confident the model is in the question extraction and strength.
    """
    question: str

class EmbeddedMeaningNode(StrengthMetric):
    """
    Extracted embedded meaning with strength and confidence. 
    The embedded meaning strength indicates how strongly the embedded meaning is present in the text.
    The confidence indicates how confident the model is in the embedded meaning extraction and strength.
    """
    embedded_meaning: str

class TangentThoughtNode(StrengthMetric):
    """
    Extracted tangent thought with strength and confidence. 
    The tangent thought strength indicates how strongly the tangent thought is present in the text.
    The confidence indicates how confident the model is in the tangent thought extraction and strength.
    """
    tangent_thought: str

class TopicScores(BaseModel):
    """
    Extracted topics from the strength with their confidence and strengths. 
    """
    topic_scores: List[TopicScoreNode]

class QuestionScores(BaseModel):
    """
    Extracted questions from the strength with their confidence and strengths. 
    """
    question_scores: List[QuestionNode]

class EmbeddedMeaningScores(BaseModel):
    """
    Extracted embedded meanings from the strength with their confidence and strengths. 
    """
    embedded_meaning_scores: List[EmbeddedMeaningNode]

class SentimentScore(BaseModel):
    """
    The sentiment score of the text.
    """
    sentiment: Sentiment
    confidence: float


class TangentThoughtScores(BaseModel):
    """
    Extracted tangent thoughts from the strength with their confidence and strengths. 
    """
    tangent_thought_scores: List[TangentThoughtNode]


class PreliminaryAnalysis(BaseModel):
    """
    Preliminary analysis of the text.
    """
    topic_scores: TopicScores
    question_scores: QuestionScores
    embedded_meaning_scores: EmbeddedMeaningScores
    sentiment_score: SentimentScore
    tangent_thought_scores: TangentThoughtScores

# %%
import instructor
from groq import Groq
import traceback
from pydantic import BaseModel
from typing import Union
from openai import OpenAI

DEFAULT_MODEL = "llama-3.3-70b-versatile"
DEFAULT_OPENAI_MODEL = "gpt-4o"

class LLMErrorResponse(BaseModel):
    error: str


def get_groq_client():
    """Returns an instance of the Groq class"""
    groq = Groq(api_key=os.getenv("GROQ_API_KEY"))
    client = instructor.from_groq(groq, mode=instructor.Mode.JSON)
    return client

def get_openai_client():
    """Returns an instance of the OpenAI class"""
    openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    return openai


def llm(
    prompt: str,
    response_model: BaseModel,
    system="You are a helpful AI assistant. The user will talk to you and its your job to provide detailed and clear responses.",
    model=DEFAULT_MODEL,
) -> Union[BaseModel, LLMErrorResponse]:
    """Calls LLM API with the given prompt. Defaults to llama-3.3-70b-versatile""",
    messages = [
            {"role": "system", "content": system},
            {"role": "user", "content": prompt},
        ]
    try:
        client = get_groq_client()
        response = client.chat.completions.create(
            messages=messages, model=model, response_model=response_model
        )
        return response
    except Exception as e:
        try:
            openai = get_openai_client()
            completion = openai.beta.chat.completions.parse(messages=messages, model=DEFAULT_OPENAI_MODEL, response_format=response_model)
            return completion.choices[0].message.parsed
        except Exception as e:
            traceback.print_exc()
            return LLMErrorResponse(error=str(e))

# %%
class GrIDEngineNucleus():
    """GrID Engine: Computing information density."""

    def __init__(self, model = "llama-3.3-70b-versatile", verbose = False):
        self.model = model 
        self.verbose = verbose
        

    def get_sentiment(self, text) -> SentimentScore:
        prompt = f"""
        Compute the sentiment of the text.
        Respond with the sentiment and confidence.
        Text: {text}
        """
        response = llm(prompt=prompt, response_model=SentimentScore)
        return response
    
    def get_embedded_meaning(self, text) -> EmbeddedMeaningScores:
        prompt = f"""
        Extract the embedded meanings from the text.
        Respond with the embedded meanings, their strengths and confidence.
        Text: {text}
        """
        response = llm(prompt=prompt, response_model=EmbeddedMeaningScores)
        return response
    
    def get_topic_scores(self, text) -> TopicScores:
        prompt = f"""
        Extract the topics from the text.
        Respond with the topics, their strengths and confidence.
        Text: {text}
        """
        response = llm(prompt=prompt, response_model=TopicScores)
        return response
    
    def get_question_scores(self, text) -> QuestionScores:
        prompt = f"""
        Extract the questions from the text.
        Respond with the questions, their strengths and confidence.
        Text: {text}
        """
        response = llm(prompt=prompt, response_model=QuestionScores)
        return response
    
    def get_tangent_thought_scores(self, text) -> TangentThoughtScores:
        prompt = f"""
        Extract the tangent thoughts from the text.
        Respond with the tangent thoughts, their strengths and confidence.
        Text: {text}
        """
        response = llm(prompt=prompt, response_model=TangentThoughtScores)
        return response
    
    def get_preliminary_analysis(self, text: str, collapse_layers = True) -> PreliminaryAnalysis:
        """Computes the preliminary analysis of the text needed for the GrID engine."""
        if collapse_layers:
            prompt = f"""
                Generate the preliminary analysis of the text.
                Respond with the topic scores, question scores, embedded meaning scores, sentiment score and tangent thought scores.
                Topic Scores: Extract the topics from the text.
                Question Scores: Extract the questions from the text.
                Embedded Meaning Scores: Extract the embedded meanings from the text.
                Sentiment Score: Compute the sentiment of the text.
                Tangent Thought Scores: Extract the tangent thoughts from the text.
                Text: {text}
            """
            preliminary_analysis = llm(prompt=prompt, response_model=PreliminaryAnalysis)
            return preliminary_analysis
        sentiment_score = self.get_sentiment(text)
        topic_scores = self.get_topic_scores(text)
        question_scores = self.get_question_scores(text)
        embedded_meaning_scores = self.get_embedded_meaning(text)
        tangent_thought_scores = self.get_tangent_thought_scores(text)
        return PreliminaryAnalysis(
            topic_scores=topic_scores,
            question_scores=question_scores,
            embedded_meaning_scores=embedded_meaning_scores,
            sentiment_score=sentiment_score,
            tangent_thought_scores=tangent_thought_scores
        )

# %%
class GrIDNaiveResult(BaseModel):
    """The result of the GrID Engine Naive."""
    information_density: float
    explanation: str

class GrIDEngineNaive(GrIDEngineNucleus):
    """GrID Engine: Computing information density using a naive approach."""
    
    def __init__(self,  model = "llama-3.3-70b-versatile", verbose = False):
        super().__init__(model, verbose=verbose)

    def compute_information_density(self, text: str, collapse_layers = False) -> GrIDNaiveResult:
        """Compute the information density of the text."""
        preliminary_analysis = self.get_preliminary_analysis(text, collapse_layers=collapse_layers)
        preliminary_analysis_json = preliminary_analysis.model_dump_json()
        system = """
            You are GrID Engine Naive. 
            GrID Engine stands for 'Generative Information Density' Engine.
            We have computed a preliminary analysis for a piece of text. 
            Your job is to understand that text, and compute the information density between 0 and 1.
            To assist you, we have extracted the following information from the text:
            - Topics: The main topics that the text discusses.
            - Questions: The questions in the text which indicates the curiosity of the text.
            - Embedded Meanings: The embedded meanings in the text which are not explicitly stated.
            - Sentiment: The sentiment of the text which indicates the overall emotion of the text.
            - Tangent Thoughts: The tangent thoughts in the text which are not directly related to the main topics.
            These components include strengths and confidence levels.
            Use this information to compute the information density.
            Explain your reasoning for the information density in 4 paragraphs in markdown in detail.
            Respond with the information density and the explanation in markdown.
        """

        prompt = f"""
            Based on the given instructions, analyse the preliminary analysis and compute the information density of the text.
            Text: {text}
            Preliminary Analysis: {preliminary_analysis_json}
        """

        response = llm(prompt=prompt, system=system, response_model=GrIDNaiveResult)
        return response

# %%
TEST_INPUT_TEXTS = [
    """
When learning something new in Software Development, it's easy to get caught up in the "consumption cycle". If you're only consuming lectures, courses, blogs and learning material but spending little to no time building things, you won't get far. 

I personally like spending 80% to 90% of my time actively building and architecting / designing / implementing and the remaining 10% / 20% of my time consuming learning material, lecture, trainings. However, it's important that you strive for a balance that works the best for you. Generally 50% consuming, 50% implementing might be a good balance, but it depends on the subject or topic you're learning and the time you have on your hands.

Sometimes, it's important to just learn enough so that you can get started with execution! There's that sweet spot of "genius" which lies between endless thought, planning, research, and the other extreme which is implementation without feedback or learnings or depth. 

It takes a while to figure this out, but as a rule of thumb; keep building, keep shipping and growth will become a natural outcome of the process!
""",
    """
Excited to be featured as an NVIDIA agents partner during Jensen's keynote at CES 🔥

2025 is the year of production knowledge agents. Everything from document research, to automated document extraction/business logic, to report generation. 

This is a great way to kick off the year. Huge shoutout to Laurie Voss + the NVIDIA team (including Daniel Glogowski) for pulling these resources together.

Blueprint: https://lnkd.in/gHFFKrgC
Video: https://lnkd.in/gQi7U6sq
Notebook: https://lnkd.in/ggmkXiYA
Blog: https://lnkd.in/ghfApUs9
""",
    """If you are leading a project, your only responsibility is to ensure it is delivered, whatever it takes. Here are a few pointers that I have followed 

1. avoid being blocked, always find a way out
2. if there is a chance of a delay, communicate early
3. always look for trade-offs and make sure we pick the right one
4. estimate timelines well; good estimation reduces chaos
5. influence others so that they prioritize our tasks
6. always reiterate key details to ensure alignment, there is no such thing as over-communication.

On the technical and execution side, here's what I ensure

1. form a deep understanding and high clarity about the project
2. create a solid plan, reduce ambiguity, and keep the team focused 
3. be agile, monitor progress, revise plan if required
4. make sure every single person involved in the project is aligned

Delivering a project requires very high focus, clarity, and persistence. Keep the big picture in mind, but execute with attention to detail.

Even if you are early in your career, follow the above, and earn some leadership brownie points.

ps: enrollments open for sys design cohort - arpitbhayani.me/course

hashtag#AsliEngineering hashtag#CareerGrowth""",
    """Yes, materials provide a chip’s physical foundation and the substance of more powerful and compact components. But they are also integral to the advanced fabrication methods and novel chip designs that underpin the industry’s rapid progress in recent decades.

For this reason, materials science is taking on a heightened importance as we grapple with the limits of miniaturization. Advanced materials are needed more than ever for the industry to unlock the new designs and technologies capable of increasing chip efficiency, speed, and power. We are seeing novel chip architectures that embrace the third dimension and stack layers to optimize surface area usage while lowering energy consumption. The industry is harnessing advanced packaging techniques, where separate “chiplets” are fused with varying functions into a more efficient, powerful single chip. This is called heterogeneous integration.""",
    """
    Data science is a good field. 
    It has a lot of potential for career growth
""",
]

# %%
from IPython.display import Markdown
from json import dumps
from pydantic import BaseModel

class FormattedResponse(BaseModel):
    content: str


def convert_markdown_to_text(markdown):
    prompt = f"""
    Convert the markdown to plain text.
    Markdown: {markdown}
    """
    response = llm(prompt=prompt, response_model=FormattedResponse)
    return response.content

def format_data_as_markdown_table(data):
    """Formats the data as a markdown table."""
    markdown = "| Text | Information Density |\n"
    markdown += "| --- | --- |\n"
    for item in data:
        trimmed_text = item['text'][:50] + (item['text'][50:] and '...')
        markdown += f"| {trimmed_text} | {item['information_density']} |\n"
    return markdown



def run_naive_grid_engine():
    grid_engine_naive = GrIDEngineNaive(verbose=True)
    results = []
    print(len(TEST_INPUT_TEXTS))
    
    for text in TEST_INPUT_TEXTS[0:2]:
        response = grid_engine_naive.compute_information_density(text)
        results.append({
            "text": text,
            "information_density": response.information_density,
            "explanation": response.explanation
        })
    formatted_tables_markdown = format_data_as_markdown_table(results)
    return Markdown(formatted_tables_markdown)

# %%
#run_naive_grid_engine()

# %%
input_text = """
Excited to be featured as an NVIDIA agents partner during Jensen's keynote at CES 🔥

2025 is the year of production knowledge agents. Everything from document research, to automated document extraction/business logic, to report generation. 

This is a great way to kick off the year. Huge shoutout to Laurie Voss + the NVIDIA team (including Daniel Glogowski) for pulling these resources together.

Blueprint: https://lnkd.in/gHFFKrgC
Video: https://lnkd.in/gQi7U6sq
Notebook: https://lnkd.in/ggmkXiYA
Blog: https://lnkd.in/ghfApUs9
"""
grid_engine_naive = GrIDEngineNaive(verbose=True)
collapse_layers = False # Set to True to collapse the layers

response = grid_engine_naive.compute_information_density(input_text, collapse_layers=True)

print(f"Text: {input_text}")
print(f"Information Density: {response.information_density}")
# Out:
# Text:
# Excited to be featured as an NVIDIA agents partner during Jensen's keynote at CES 🔥
#
# 2025 is the year of production knowledge agents. Everything from document research, to automated document extraction/business logic, to report generation.
#
# This is a great way to kick off the year. Huge shoutout to Laurie Voss + the NVIDIA team (including Daniel Glogowski) for pulling these resources together.
#
# Blueprint: https://lnkd.in/gHFFKrgC
# Video: https://lnkd.in/gQi7U6sq
# Notebook: https://lnkd.in/ggmkXiYA
# Blog: https://lnkd.in/ghfApUs9
#
# Information Density: 0.85

# %%
input_text = """
Excited to be featured as an NVIDIA agents partner during Jensen's keynote at CES 🔥

2025 is the year of production knowledge agents. Everything from document research, to automated document extraction/business logic, to report generation. 

This is a great way to kick off the year. Huge shoutout to Laurie Voss + the NVIDIA team (including Daniel Glogowski) for pulling these resources together.

Blueprint: https://lnkd.in/gHFFKrgC
Video: https://lnkd.in/gQi7U6sq
Notebook: https://lnkd.in/ggmkXiYA
Blog: https://lnkd.in/ghfApUs9
"""
grid_engine_naive = GrIDEngineNaive(verbose=True)
collapse_layers = True # Set to True to collapse the layers

response = grid_engine_naive.compute_information_density(input_text, collapse_layers=True)

print(f"Text: {input_text}")
print(f"Information Density: {response.information_density}")
# Out:
# Text:
# Excited to be featured as an NVIDIA agents partner during Jensen's keynote at CES 🔥
#
# 2025 is the year of production knowledge agents. Everything from document research, to automated document extraction/business logic, to report generation.
#
# This is a great way to kick off the year. Huge shoutout to Laurie Voss + the NVIDIA team (including Daniel Glogowski) for pulling these resources together.
#
# Blueprint: https://lnkd.in/gHFFKrgC
# Video: https://lnkd.in/gQi7U6sq
# Notebook: https://lnkd.in/ggmkXiYA
# Blog: https://lnkd.in/ghfApUs9
#
# Information Density: 0.83

# %%
def compare_runtime_with_collapsing(input_text = TEST_INPUT_TEXTS[0]):
    print(f"Input Text: {input_text}")
    import time
    grid_engine_naive = GrIDEngineNaive(verbose=True)
    start_time = time.time()
    response = grid_engine_naive.compute_information_density(input_text, collapse_layers=True)
    print(f"Information Density (no layer collapsing): {response.information_density}")
    end_time = time.time()
    time_with_collapsing = end_time - start_time
    print(f"Time with collapsing: {time_with_collapsing}")

    start_time = time.time()
    response = grid_engine_naive.compute_information_density(input_text, collapse_layers=False)
    end_time = time.time()
    time_without_collapsing = end_time - start_time
    print(f"Information Density (with layer collapsing): {response.information_density}")
    print(f"Time without collapsing: {time_without_collapsing}")

    time_delta_percent = ((time_with_collapsing - time_without_collapsing) / time_with_collapsing) * 100
    print(f"Time difference (collapsing is better by?): {time_delta_percent}%")
    return time_with_collapsing, time_without_collapsing

compare_runtime_with_collapsing()
# Out:
# Input Text:
# When learning something new in Software Development, it's easy to get caught up in the "consumption cycle". If you're only consuming lectures, courses, blogs and learning material but spending little to no time building things, you won't get far.
#
# I personally like spending 80% to 90% of my time actively building and architecting / designing / implementing and the remaining 10% / 20% of my time consuming learning material, lecture, trainings. However, it's important that you strive for a balance that works the best for you. Generally 50% consuming, 50% implementing might be a good balance, but it depends on the subject or topic you're learning and the time you have on your hands.
#
# Sometimes, it's important to just learn enough so that you can get started with execution! There's that sweet spot of "genius" which lies between endless thought, planning, research, and the other extreme which is implementation without feedback or learnings or depth.
#
# It takes a while to figure this out, but as a rule of thumb; keep building, keep shipping and growth will become a natural outcome of the process!
#
# Information Density (no layer collapsing): 0.8
# Time with collapsing: 13.719287872314453
# Information Density (with layer collapsing): 0.88
# Time without collapsing: 25.69143509864807
# Time difference (collapsing is better by?): -87.26507773405231%
# (13.719287872314453, 25.69143509864807)
