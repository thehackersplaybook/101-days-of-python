# %% [markdown]
# # FireCrawl x LangChain Documentation RAG 🔥
#
#
#
# <div style="display:flex; align-items:center; padding: 50px;">
# <p style="margin-right:10px;">
#     <img height="200px" style="width:auto;" width="200px" src="https://avatars.githubusercontent.com/u/192148546?s=400&u=95d76fbb02e6c09671d87c9155f17ca1e4ef8f21&v=4">
# </p>
# <p style="margin-right:10px;">
#     <img  height="200px" src="https://raw.githubusercontent.com/mendableai/firecrawl/main/img/firecrawl_logo.png">
# </p>
# <p style="margin-right:10px;">
#     <img  height="200px" src="https://images.contentstack.io/v3/assets/bltf2fca5bf44f5e817/blt34d9fdb635976e4a/669e80a79fecd86c50d59f6d/Lang_Square.png">
# </p>
#
#
# </div>
#
# A simple and effective implementation of Naive RAG (Retrieval Augmented Generation) using FireCrawl and LangChain! 🚀
#
# - Provide a link to your Python documentation.
#
# - FireCrawl crawls and scrapes the documentation.
#
# - Use LangChain to embed the documents and store it in an in-memory vector store.
#
# - Use prompt templates to use a RAG template which has the 'query' and 'context'.
#
# - Receive detailed answers from the LLM using your documentation.

# %% [markdown]
# # Step 1: Install Requirements ⚙️
#
# The requirements are already specified in the `requirements.txt` file. We simply use our utility to install the requirements.

# %%
import os
requirements_installed = False
max_retries = 3
retries = 0

def install_requirements():
    """Installs the requirements from requirements.txt file"""
    global requirements_installed
    if requirements_installed:
        print('Requirements already installed.')
        return
 
    print('Installing requirements...')
    install_status = os.system('pip install -r requirements.txt')
    if install_status == 0:
        print('Requirements installed successfully.')
        requirements_installed = True
    else:
        print('Failed to install requirements.')
        if retries < max_retries:
            print('Retrying...')
            retries += 1
            return install_requirements()
        exit(1)
    return

# %%
install_requirements()
# Out:
# Installing requirements...
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: pydantic==2.10.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.10.4)
# Requirement already satisfied: pydantic-settings==2.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: pydantic_core==2.27.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.27.2)
# Requirement already satisfied: crewai==0.95.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.95.0)
# Requirement already satisfied: crewai-tools==0.25.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.25.8)
# Requirement already satisfied: langchain==0.3.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.3.14)
# Requirement already satisfied: langchain-anthropic==0.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.3.1)
# Requirement already satisfied: langchain-cohere==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.3.4)
# Requirement already satisfied: langchain-community==0.3.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (0.3.14)
# Requirement already satisfied: langchain-core==0.3.29 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.3.29)
# Requirement already satisfied: langchain-experimental==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.3.4)
# Requirement already satisfied: langchain-openai==0.2.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.2.14)
# Requirement already satisfied: langchain-text-splitters==0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.3.4)
# Requirement already satisfied: firecrawl-py==1.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pydantic==2.10.4->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pydantic==2.10.4->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (4.7.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (0.35.0)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.56.10)
# Requirement already satisfied: openai>=1.13.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.59.3)
# Requirement already satisfied: openpyxl>=3.1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (0.11.5)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai==0.95.0->-r requirements.txt (line 5)) (0.5.14)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.1.126)
# Requirement already satisfied: lancedb>=0.5.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.17.0)
# Requirement already satisfied: linkup-sdk>=0.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: pyright>=1.1.350 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.1.391)
# Requirement already satisfied: pytest>=8.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (8.3.4)
# Requirement already satisfied: pytube>=15.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: scrapegraph-py>=1.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: selenium>=4.18.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.27.1)
# Requirement already satisfied: serpapi>=0.1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.1.5)
# Requirement already satisfied: spider-client>=0.1.25 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.1.25)
# Requirement already satisfied: weaviate-client>=4.9.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.10.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (3.11.11)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (0.1.147)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain==0.3.14->-r requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: anthropic<1,>=0.41.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (0.42.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-cohere==0.3.4->-r requirements.txt (line 9)) (5.13.5)
# Requirement already satisfied: pandas>=1.4.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-cohere==0.3.4->-r requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-cohere==0.3.4->-r requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-community==0.3.14->-r requirements.txt (line 10)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-community==0.3.14->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-core==0.3.29->-r requirements.txt (line 11)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-core==0.3.29->-r requirements.txt (line 11)) (24.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langchain-openai==0.2.14->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: websockets in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from firecrawl-py==1.8.0->-r requirements.txt (line 15)) (14.1)
# Requirement already satisfied: nest-asyncio in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from firecrawl-py==1.8.0->-r requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->-r requirements.txt (line 7)) (1.18.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (0.8.2)
# Requirement already satisfied: sniffio in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 5)) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 5)) (2.10.1)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.6)
# Requirement already satisfied: build>=1.0.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.7.5)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.50b0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.10.13)
# Requirement already satisfied: rich>=10.11.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (1.10.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (2.32.0.20241016)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 10)) (3.23.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.75.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.1.44)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.37 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.1.39)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.7.7)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai==0.95.0->-r requirements.txt (line 5)) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai==0.95.0->-r requirements.txt (line 5)) (3.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.29->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: deprecation in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: pylance==0.20.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: pyarrow>=14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pylance==0.20.0->lancedb>=0.5.4->crewai-tools==0.25.8->-r requirements.txt (line 6)) (18.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (4.23.0)
# Requirement already satisfied: et-xmlfile in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai==0.95.0->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (5.29.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (0.50b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere==0.3.4->-r requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 5)) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 5)) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai==0.95.0->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyright>=1.1.350->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.9.1)
# Requirement already satisfied: iniconfig in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (8.31.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from requests>=2.31.0->crewai-tools==0.25.8->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from requests>=2.31.0->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2024.12.14)
# Requirement already satisfied: trio~=0.17 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.28.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: ijson in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from spider-client>=0.1.25->crewai-tools==0.25.8->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: validators==0.34.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.34.0)
# Requirement already satisfied: authlib<1.3.2,>=1.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: grpcio-tools<2.0.0,>=1.66.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.68.1)
# Requirement already satisfied: grpcio-health-checking<2.0.0,>=1.66.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.68.1)
# Requirement already satisfied: Mako in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.3.8)
# Requirement already satisfied: pyproject_hooks in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai==0.95.0->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.41.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.24.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.0.6)
# Requirement already satisfied: cachetools in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: setuptools in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from grpcio-tools<2.0.0,>=1.66.2->weaviate-client>=4.9.6->crewai-tools==0.25.8->-r requirements.txt (line 6)) (75.6.0)
# Requirement already satisfied: httpcore==1.* in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.41.0->langchain-anthropic==0.3.1->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: decorator in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: stack_data in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai==0.95.0->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai==0.95.0->-r requirements.txt (line 5)) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: requests-oauthlib in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.9)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.12.2)
# Requirement already satisfied: coloredlogs in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (24.12.23)
# Requirement already satisfied: sympy in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.50b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: sortedcontainers in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: outcome in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.14->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: httptools>=0.6.3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.0.3)
# Requirement already satisfied: pycparser in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai==0.95.0->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.68.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: filelock in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (2024.12.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.95.0->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai==0.95.0->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/adityapatange/thehackersplaybook/engineering/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.37->embedchain>=0.1.114->crewai-tools==0.25.8->-r requirements.txt (line 6)) (4.0.0)
# Requirements installed successfully.

# %% [markdown]
# # Step 2: Setup Environment Variables 🏕️
#
# Make sure you have added `FIRECRAWL_API_KEY` and `OPENAI_API_KEY` to your `.env` file.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Step 3: Initialize FireCrawl Client 🔥
#
# This method intitializes the FireCrawl App with the API key.

# %%
from firecrawl import FirecrawlApp

def get_firecrawl_client():
    return FirecrawlApp(api_key=os.getenv('FIRECRAWL_API_KEY'))

# %% [markdown]
# # Step 4: Crawling & Scraping Utilities 🕷️
#
# We fetch the documentation links and then scrape each page in markdown format. To achieve this, we define a set of utility methods that we will call in our runner.

# %%
from typing import List

cache = {}

def get_doc_links(app: FirecrawlApp, input_url: str) -> List[str]:
    """Gets the documentation links from the given URL."""
    cache_key = f"{input_url}_links"
    cached_links = cache.get(cache_key)
    if cached_links:
        print(f'Using cached links for URL: {input_url}')
        return cached_links
    
    app = get_firecrawl_client()
    crawl_result = app.map_url(input_url)

    success = crawl_result['success']

    if not success:
        raise RuntimeError(f'Failed to get links from URL: {input_url}')
    
    links = crawl_result['links']
    cache[cache_key] = links

    return links


def get_single_doc_from_link(app: FirecrawlApp, link: str) -> str:
    """Gets the documentation from the given link."""
    cached_doc = cache.get(link)
    if cached_doc:
        print(f'Using cached docs for URL: {link}')
        return cached_doc

    scrape_result = None
    try:
        scrape_result = app.scrape_url(link, params={'formats': ['markdown']})
    except Exception as e:
        print(f'Failed to get docs from URL: {link}')
        print(e)

    if not scrape_result:
        return None

    success = scrape_result['metadata']['statusCode'] == 200

    if not success:
       print(f'Failed to get docs from URL: {link}')
       return None
    
    markdown = scrape_result['markdown']
    cache[link] = markdown

    return markdown

def get_docs_from_links(app: FirecrawlApp, links: List[str], verbose = False) -> List[str]:
    """Gets the documentation from the given list of links."""
    docs = []

    for link in links:
        if verbose:
            print(f'Getting docs from URL: {link}')
        markdown = get_single_doc_from_link(app, link)
        if markdown:
            docs.append(markdown)
            if verbose:
                print(f'Fetched docs from URL: {link}')

    return docs

# %% [markdown]
# # Step 5: Vector Store & Embeddings 🔮
#
# Setup the vector store and embeddings using Open AI embeddings. These methods will be used to embed our documentation and load it into the vector DB for retrieval.

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter

DEFAULT_EMBEDDING_MODEL = "text-embedding-3-small"

vector_store = None


def get_embeddings() -> List[List[float]]:
    """Gets the embeddings for the given list of documents."""
    embeddings = OpenAIEmbeddings(model=DEFAULT_EMBEDDING_MODEL)
    return embeddings


def build_vectorstore(docs: List[str]) -> InMemoryVectorStore:
    """Builds a vector store from the given list of documents."""
    global vector_store
    if vector_store:
        print("Vector store already built. Return pre-computed vector store.")
        return vector_store
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1024,
        chunk_overlap=20,
        length_function=len,
        is_separator_regex=False,
    )
    vector_docs = text_splitter.create_documents(docs)
    embeddings = get_embeddings()
    vector_store = InMemoryVectorStore(embeddings)
    vector_store.add_documents(vector_docs)
    return vector_store

# %% [markdown]
# # Step 6: LLM interface and RAG prompt 🧠
#
# We dynamically return our LLM client based on the model and provider. If you wish to use anthropic instead of openai, accordingly supply the `ANTHROPIC_API_KEY` in your `.env` file. For defaults, we use Open AI and GPT-4o. Additionally, we define a simple RAG prompt which holds the 'query' and 'context'.

# %%
from langchain_openai import ChatOpenAI
from langchain_anthropic import Anthropic
from langchain_core.prompts import ChatPromptTemplate

DEFAULT_PROVIDER = "openai"
DEFAULT_OPENAI_MODEL = "gpt-4o"
DEFAULT_ANTHROPIC_MODEL = "claude-3-5-sonnet-latest"

def get_llm(provider = DEFAULT_PROVIDER, model = DEFAULT_OPENAI_MODEL) -> ChatOpenAI:
    """Gets the language model."""
    if provider == "openai":
        return ChatOpenAI(model=model)
    elif provider == "anthropic":
        return Anthropic(model=model)
    
def get_rag_prompt() -> ChatPromptTemplate:
    """Gets the RAG prompt."""
    system = """
        You are an AI agent that can answer questions about software development.
        Given a query and context about the query, provide a factual, and detailed response. 
        The response should be relevant to the query and context.
        Simply respond with the answer to the query.
    """

    user = """
        Query: {query}
        Context: {context}
    """

    return ChatPromptTemplate.from_messages([
        ("system", system),
        ("user", user)
    ])


def rag_search(query: str, docs: List[str]) -> str:
    """Performs a RAG search."""
    llm = get_llm()
    vector_store = build_vectorstore(docs)
    matched_docs = vector_store.similarity_search(query, num_results=5)
    matched_docs = [doc.page_content for doc in matched_docs]
    context = "\n".join(matched_docs)
    prompt = get_rag_prompt()
    prompt_formatted = prompt.invoke(input={"query": query, "context": context})
    llm_response = llm.invoke(input=prompt_formatted)
    return llm_response.content

# %% [markdown]
# # Step 7: Runner! 🏃🏻
#
# Define our 'entry point' — from this point all our previously defined methods will be called!

# %%
input_url = "https://pyparsing-docs.readthedocs.io/en/latest/"

def run(query = None, verbose = False, user_input = False):
    """Runs the program."""
    print("Starting FireCrawl x LangChain Documentation RAG! 🚀")
    app = get_firecrawl_client()
    if verbose:
        print(f'Getting links from URL: {input_url}')

    if query and user_input:
        print("User input is enabled. Ignoring the query parameter.")

    links = get_doc_links(app, input_url)
    if verbose:
        print(f"Fetched {len(links)} links.")
        print("Fetching docs from links...")
    docs = get_docs_from_links(app, links, verbose=verbose)
    if verbose:
        print(f"Fetched {len(docs)} docs.")
    if verbose:
        print("Built vector store.")
    if user_input:
        query = input("Enter your query: ")
    response = rag_search(query, docs)
    print("\nAI Response:", response)
    print("Done! ✨")

# %% [markdown]
# # Step 8: Run ⚡️
#
# Run the program. Feel free to adjust the input parameters as per your liking.

# %%
# Input Parameters: Adjust the query and user_input parameters as needed
query = "How to parse a string in Python?"
user_input = False # If set to 'true' ignores 'query' parameter and takes user input

# Run the program! 🚀
run(query=query, verbose=False, user_input=user_input)
# Out:
# Starting FireCrawl x LangChain Documentation RAG! 🚀
#
# AI Response: To parse a string in Python using the `pyparsing` module, follow these steps:
#
# 1. **Define Tokens and Patterns**: First, define the tokens and patterns you want to match by using the appropriate `pyparsing` classes like `Word`, `Literal`, etc. You can assign these to a variable and optionally specify result names or parse actions to process matched tokens.
#
# 2. **Parse the String**: Use the `parse_string()` method on the pattern variable you created. This method takes the input string as an argument and parses it according to the defined pattern.
#
# 3. **Handle Results**: The `parse_string()` method returns a `ParseResults` object, which can be accessed like a list, dictionary, or object with named attributes, depending on how you defined your parser.
#
# Here is an example to parse dates in the format `YYYY/MM/DD`:
#
# ```python
# from pyparsing import Word, nums, ParseException
#
# # Parse action to convert tokens from str to int
# def convert_to_int(toks):
#     return int(toks[0])
#
# # Parse action to validate the date
# def is_valid_date(instring, loc, toks):
#     from datetime import date
#     year, month, day = toks[::2]
#     try:
#         date(year, month, day)
#     except ValueError:
#         raise ParseException(instring, loc, "invalid date given")
#
# integer = Word(nums)
#
# # Define the pattern
# date_str = integer.setParseAction(convert_to_int) + '/' + integer.setParseAction(convert_to_int) + '/' + integer.setParseAction(convert_to_int)
#
# # Parse a sample date
# result = date_str.parse_string("2023/10/25", parseAll=True)
# print(result)
# ```
#
# This example shows how to define a pattern for a date and perform actions like converting strings to integers and validating the date as it is being parsed. You can adapt this approach to suit other parsing needs by defining different tokens and parse actions.
# Done! ✨

# %% [markdown]
# # Thank You for visiting The Hackers Playbook! 🌐
#
# If you liked this research material;
#
# - [Subscribe to our newsletter.](https://thehackersplaybook.substack.com)
#
# - [Follow us on LinkedIn.](https://www.linkedin.com/company/the-hackers-playbook/)
#
# - [Leave a star on our GitHub.](https://www.github.com/thehackersplaybook)
